# %%
import pandas as pd

# %%
df = pd.read_csv("phone_usage.csv")
df
# Out:
#                                            ï»¿name  \
# 0                                            China
# 1                                            India
# 2                                    United States
# 3                                        Indonesia
# 4                                           Russia
# ..                                             ...
# 220              Falkland Islands (Islas Malvinas)
# 221                                     Montserrat
# 222  Saint Helena, Ascension, and Tristan da Cunha
# 223                                 American Samoa
# 224                              Wallis and Futuna
#
#                                             slug          value  \
# 0                                          china  1,810,000,000
# 1                                          india  1,140,000,000
# 2                                  united-states    386,000,000
# 3                                      indonesia    352,000,000
# ...

# %%
df.columns
# Out:
# Index(['ï»¿name', 'slug', 'value', 'date_of_information', 'ranking', 'region'], dtype='object')

# %%
df.shape #
# Out:
# (225, 6)

# %%
df_new = df[["slug" , "ranking"]]
df_new
# Out:
#                                             slug  ranking
# 0                                          china        1
# 1                                          india        2
# 2                                  united-states        3
# 3                                      indonesia        4
# 4                                         russia        5
# ..                                           ...      ...
# 220              falkland-islands-islas-malvinas      221
# 221                                   montserrat      222
# 222  saint-helena-ascension-and-tristan-da-cunha      223
# 223                               american-samoa      224
# 224                            wallis-and-futuna      225
#
# [225 rows x 2 columns]

# %%
df[df["slug"] == "china"]
# Out:
#   ï»¿name   slug          value  date_of_information  ranking  \
# 0   China  china  1,810,000,000                 2023        1
#
#                     region
# 0  East and Southeast Asia

# %%
# df["new_col"] = df["ranking"] * 10
# Out:
#                                            ï»¿name  \
# 0                                            China
# 1                                            India
# 2                                    United States
# 3                                        Indonesia
# 4                                           Russia
# ..                                             ...
# 220              Falkland Islands (Islas Malvinas)
# 221                                     Montserrat
# 222  Saint Helena, Ascension, and Tristan da Cunha
# 223                                 American Samoa
# 224                              Wallis and Futuna
#
#                                             slug          value  \
# 0                                          china  1,810,000,000
# 1                                          india  1,140,000,000
# 2                                  united-states    386,000,000
# 3                                      indonesia    352,000,000
# ...

# %%
#rename columns
df.columns = ['country', 'slug', 'value', 'date', 'ranking', 'region']
df
# Out:
#                                            country  \
# 0                                            China
# 1                                            India
# 2                                    United States
# 3                                        Indonesia
# 4                                           Russia
# ..                                             ...
# 220              Falkland Islands (Islas Malvinas)
# 221                                     Montserrat
# 222  Saint Helena, Ascension, and Tristan da Cunha
# 223                                 American Samoa
# 224                              Wallis and Futuna
#
#                                             slug          value  date  \
# 0                                          china  1,810,000,000  2023
# 1                                          india  1,140,000,000  2022
# 2                                  united-states    386,000,000  2023
# ...

# %%
df[df["region"] == 'Europe'].country.values
# Out:
# array(['Germany', 'United Kingdom', 'Italy', 'France', 'Spain', 'Poland',
#        'Ukraine', 'Romania', 'Netherlands', 'Sweden', 'Czechia',
#        'Portugal', 'Belgium', 'Belarus', 'Greece', 'Austria',
#        'Switzerland', 'Hungary', 'Serbia', 'Bulgaria', 'Slovakia',
#        'Denmark', 'Finland', 'Norway', 'Ireland', 'Croatia', 'Moldova',
#        'Lithuania', 'Bosnia and Herzegovina', 'Slovenia', 'Albania',
#        'Latvia', 'Estonia', 'North Macedonia', 'Kosovo', 'Cyprus',
#        'Montenegro', 'Luxembourg', 'Malta', 'Iceland', 'Andorra',
#        'Jersey', 'Guernsey', 'Faroe Islands', 'Liechtenstein', 'Monaco',
#        'San Marino', 'Gibraltar'], dtype=object)

# %%
df[df["country"]== "Sri Lanka"]
# Out:
#       country       slug       value  date  ranking      region
# 46  Sri Lanka  sri-lanka  30,000,000  2023       47  South Asia

# %%
#what is the avarage mobile usage in England?
df[df["country"]== "United Kingdom"]
# Out:
#            country            slug       value  date  ranking  region
# 20  United Kingdom  united-kingdom  84,300,000  2023       21  Europe

# %%
df[df["region"]== "South Asia"]
# Out:
#          country         slug          value  date  ranking      region
# 1          India        india  1,140,000,000  2022        2  South Asia
# 8     Bangladesh   bangladesh    191,000,000  2023        9  South Asia
# 9       Pakistan     pakistan    189,000,000  2023       10  South Asia
# 41         Nepal        nepal     38,200,000  2021       42  South Asia
# 46     Sri Lanka    sri-lanka     30,000,000  2023       47  South Asia
# 58   Afghanistan  afghanistan     23,000,000  2023       59  South Asia
# 168       Bhutan       bhutan        752,000  2023      169  South Asia
# 170     Maldives     maldives        745,000  2023      171  South Asia

# %%
# Which country has the  highest mobile uage in south asian region
df[df["region"]== "South Asia"].max()
# Out:
# country     Sri Lanka
# slug        sri-lanka
# value      1140000000
# date             2023
# ranking           171
# region     South Asia
# dtype: object

# %%
df.dtypes
# Out:
# country    object
# slug       object
# value      object
# date        int64
# ranking     int64
# region     object
# dtype: object

# %%
"Umair".replace("U", "_")
# Out:
# '_mair'

# %%
def replace_comma(value):
  return value.replace(",", "")

# %%
df["value"] = df["value"].apply(replace_comma)

# %%
df["value"]
# Out:
# 0      1810000000
# 1      1140000000
# 2       386000000
# 3       352000000
# 4       245000000
#           ...
# 220          6000
# 221          5000
# 222          4000
# 223          2250
# 224             0
# Name: value, Length: 225, dtype: object

# %%
df["value"] = df["value"].astype("int64")

# %%
df["value"]
# Out:
# 0      1810000000
# 1      1140000000
# 2       386000000
# 3       352000000
# 4       245000000
#           ...
# 220          6000
# 221          5000
# 222          4000
# 223          2250
# 224             0
# Name: value, Length: 225, dtype: int64

# %%
# df["value"] = df['value'].apply(lambda v : v.replace(",", ""))
df["value"].astype("int64")
# Out:
# 0      1810000000
# 1      1140000000
# 2       386000000
# 3       352000000
# 4       245000000
#           ...
# 220          6000
# 221          5000
# 222          4000
# 223          2250
# 224             0
# Name: value, Length: 225, dtype: int64

# %%
df['ranking']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 220    221
# 221    222
# 222    223
# 223    224
# 224    225
# Name: ranking, Length: 225, dtype: int64

# %%
# Which country has the  highest mobile uage in afrian regiondf['value']

# %%
# analyse the growth of usage whole over the world year by year!
